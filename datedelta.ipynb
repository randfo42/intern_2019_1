# %%
import pandas as pd
import numpy as np
import datetime
import time # http://inma.tistory.com/96
import glob
import datetime as dt
import json,pickle
import math
import gc,glob
import os
import matplotlib as mpl
import matplotlib.pylab as plt
import sqlalchemy
from sqlalchemy import create_engine
import seaborn as sns

# %%
len(df)
# Out:
# 471265

# %%
import datetime

# %%
matplotlib.dates.date2num(df['reg_dt'][0].date())
# Out:
# 736305.0

# %%
df['reg_dt'][0].date()
# Out:
# datetime.date(2016, 12, 7)

# %%
df['reg_dt'][400000].date()
# Out:
# datetime.date(2018, 8, 14)

# %%
df['reg_dt'][400000].date()-df['reg_dt'][0].date()
# Out:
# datetime.timedelta(days=615)

# %%
x1=[]
x2=[]
for idx in range(0,len(df['reg_dt'])):
    x1.append(df['reg_dt'][idx].date())
    x2.append(df['deal_dt'][idx].date())

# %%
x1[0].year
# Out:
# 2016

# %%
test=[]
for idx in x1:
    test.append(idx.year)

# %%
list(set(test))
# Out:
# [2016, 2017, 2018, 2019]

# %%
delta=[[],[],[],[]]
for idx in range(0,len(x1)):
     delta[x2[idx].year-2016].append((x1[idx]-x2[idx]).days)

# %%
x3=[]
for idx in range(0,len(x1)):
    x3.append((x1[idx]-x2[idx]).days)

# %%
import matplotlib
import matplotlib.dates as mdates

# %%
#myFmt = mdates.DateFormatter('%Y:%m-%d')
#plt.gca().xaxis.set_major_formatter(myFmt)
#plt.gcf().autofmt_xdate()

# %%
f1 = plt.figure(figsize=(30,20))
plt.subplot(221)
sns.distplot(delta[0])
plt.title('2016')
plt.subplot(222)
sns.distplot(delta[1])
plt.title('2017')
plt.subplot(223)
sns.distplot(delta[2])
plt.title('2018')
plt.subplot(224)
sns.distplot(delta[3])
plt.title('2019')


plt.show()
f1.savefig('year_delta.png')
